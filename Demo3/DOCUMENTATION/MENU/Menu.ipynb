# %% [markdown]
# # Menu
#
#
# | Option |                        Description                               |
# |--------|------------------------------------------------------------------|
# |    0   |          Exit                                                    |
# |    1   |          [Add New Account](./AddNewAccount.ipynb)                |
# |    2   |          [Add New Transaction](./AddNewTransaction.ipynb)        |
# |    3   |          Change View                                             |
# |    4   |          Account Transaction                                     |
